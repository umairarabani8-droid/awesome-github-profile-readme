# %% [markdown]
# <a href="https://colab.research.google.com/github/umairarabani8-droid/awesome-github-profile-readme/blob/master/learned-1%20python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
materi pertama pembelajaran tentang python

# %%
a=2
b=3
c=a+b
print (c)
# Out:
# 5
